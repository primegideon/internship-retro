# %% [markdown]
# <a href="https://colab.research.google.com/github/primegideon/internship-retro/blob/feature%2Ftaxi-ml-pipeline/ml-notebooks/chicago_taxi_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the tools
import pandas as pd

# load the csv file from session storage
df = pd.read_csv('chicago_taxi_sample.csv')

# display first 5 rows to confirm load
df.head()
# Out:
#              trip_start_timestamp  trip_miles  trip_seconds payment_type  \
# 0  2023-01-30 17:30:00.000000 UTC        10.5        1680.0    No Charge
# 1  2023-04-03 02:30:00.000000 UTC         9.1         900.0      Dispute
# 2  2023-07-13 18:15:00.000000 UTC        16.6        3660.0      Dispute
# 3  2023-07-06 10:30:00.000000 UTC         0.2          60.0    No Charge
# 4  2023-07-06 11:15:00.000000 UTC         0.1        2940.0      Dispute
#
#     fare  tips  trip_total
# 0  29.00   0.0       31.00
# 1  24.25   0.0       31.25
# 2  45.00   0.0       50.00
# 3   3.75   0.0        4.75
# 4  45.50   0.0       51.00
